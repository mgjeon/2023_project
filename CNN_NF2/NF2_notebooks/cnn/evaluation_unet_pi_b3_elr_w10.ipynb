# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import torch
import numpy as np
from tool.model import Unet
from tool.evaluate import *

# %%
model = Unet().to('cuda')

# %%
inputs = torch.Tensor(np.load('inputs.npy')).to('cuda')
labels = np.load('outputs.npy')

# %%
inputs_test = torch.Tensor(np.load('inputs_test.npy')).to('cuda')
labels_test = np.load('outputs_test.npy')

# %%
checkpoint = torch.load('model_unet_pi_b3_elr_w10/model_10000.pt')
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# Unet(
#   (maxpool): MaxPool3d(kernel_size=(2, 2, 1), stride=(2, 2, 1), padding=0, dilation=1, ceil_mode=False)
#   (encoder1): Sequential(
#     (0): Conv3d(1, 32, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(32, 64, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (encoder2): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(64, 128, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (encoder3): Sequential(
#     (0): Conv3d(128, 128, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(128, 256, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (encoder4): Sequential(
#     (0): Conv3d(256, 256, kernel_size=(2, 2, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(256, 512, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (upconv3): ConvTranspose3d(512, 512, kernel_size=(2, 2, 1), stride=(2, 2, 1), padding=(1, 1, 0))
#   (decoder3): Sequential(
#     (0): Conv3d(768, 256, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(256, 256, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (upconv2): ConvTranspose3d(256, 256, kernel_size=(2, 2, 1), stride=(2, 2, 1))
#   (decoder2): Sequential(
#     (0): Conv3d(384, 128, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(128, 128, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (upconv1): ConvTranspose3d(128, 128, kernel_size=(3, 3, 1), stride=(2, 2, 1))
#   (decoder1): Sequential(
#     (0): Conv3d(192, 64, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (1): ReLU()
#     (2): Conv3d(64, 64, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
#     (3): ReLU()
#   )
#   (final): Conv3d(64, 50, kernel_size=(3, 3, 1), stride=(1, 1, 1), padding=(1, 1, 0))
# )

# %%
idx = 0

# %%
b_norm = 2500

# %%
b = model(torch.permute(inputs[idx, ...], (3, 2, 1, 0))[None, ...])*b_norm
b = b.cpu().detach().numpy().squeeze().transpose(2, 1, 0, 3)

B = labels[idx, ...]*b_norm
B = B.transpose(1, 2, 3, 0)

# %%
b.shape, B.shape
# Out:
# ((513, 257, 50, 3), (513, 257, 50, 3))

# %%
b_test = model(torch.permute(inputs_test[idx, ...], (3, 2, 1, 0))[None, ...])*b_norm
b_test = b_test.cpu().detach().numpy().squeeze().transpose(2, 1, 0, 3)

B_test = labels_test[idx, ...]*b_norm
B_test = B_test.transpose(1, 2, 3, 0)

# %%
print(metric(b, B))
plot_overview(b, B, z=25, b_norm=100)
plot_sample(b, B)
# Out:
# {'c_vec': 0.986255, 'c_cs': 0.9378330716544928, 'c_cs_ep': 0.7974597431754916, "E_n'": 0.7643820494413376, "E_m'": 0.4514594473646286, "E_m'_ep": -405925.78576406423, 'eps': 0.9565051}

# %%
print(metric(b_test, B_test))
plot_overview(b_test, B_test, z=25, b_norm=100)
plot_sample(b_test, B_test)
# Out:
# {'c_vec': 0.9028972, 'c_cs': 0.632155968173785, 'c_cs_ep': 0.5142744669715794, "E_n'": 0.3869834542274475, "E_m'": -7.82148163317936, "E_m'_ep": -453091.02708595956, 'eps': 1.0251231}
