# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

from nf2.evaluation.unpack import load_cube
import numpy as np

# %%
b_norm = 2500

# %%
extrapolated_field = "/userhome/jeon_mg/workspace/_data/nf2_isee/11158_input_0/extrapolation_result.nf2"
b = load_cube(extrapolated_field, progress=True)
# np.save('data/nf2_11158_0.npy', b)
b = np.load('data/nf2_11158_0.npy')
# Out:
# 100%|██████████| 6593/6593 [00:07<00:00, 891.79it/s]

# %%
b = b*b_norm*b_norm

# %%
b.shape
# Out:
# (513, 257, 50, 3)

# %%
B_l= np.load('data/outputs_11158.npy')*b_norm

# %%
B_l.shape
# Out:
# (66, 3, 513, 257, 50)

# %%
B_l = B_l.transpose(0, 2, 3, 4, 1)
B_l.shape
# Out:
# (66, 513, 257, 50, 3)

# %%
B = B_l[0]
B.shape
# Out:
# (513, 257, 50, 3)

# %%
from tools.ploting import plot_overview
from tools.metric import evaluate
from tools.metric_another import metrics

# %%
plot_overview(b, B, z=0, b_norm=1000)

# %%
plot_overview(b, B, z=25, b_norm=100)

# %%
evaluate(b, B)

# %%
metrics(b, B)
