# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

from tools.evaluate import *
from tools.isee import load_b_from_nc_file
from tools.nf2 import load_b_from_nf2_file

# %%
B = load_b_from_nc_file("/mnt/obsdata/isee_nlfff_v1.2/12673/12673_20170906_083600.nc")

# %%
b = load_b_from_nf2_file("/userhome/jeon_mg/workspace/_data/isee/noaa_12673/20170906_083600/extrapolation_result.nf2")
isee_12673 = evaluator(b, B)
# Out:
# 100%|██████████| 33884/33884 [00:39<00:00, 850.04it/s]
# {'c_vec': 0.5222934378187164, 'c_cs': 0.15768290329131726, "E_n'": -3.366572370544576, "E_m'": -31.85976310073528, 'eps': 3.7381373178260042}

# %%
b = load_b_from_nf2_file("/userhome/jeon_mg/workspace/_data/isee/noaa_12673/20170906_083600_pf/extrapolation_result.nf2")
isee_12673_pf = evaluator(b, B)
# Out:
# 100%|██████████| 33884/33884 [00:38<00:00, 882.14it/s]
# {'c_vec': 0.8930818992758658, 'c_cs': 0.5924872723075466, "E_n'": 0.0763254374515343, "E_m'": -1.7512459569918595, 'eps': 1.1637350104359865}
